# %%
#Importing Packages
from functools import reduce
import pandas as pd
import warnings
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
warnings.filterwarnings('ignore')

# %%
df_user = pd.read_csv('Dataset/User_activity.txt')
df_user= df_user.transpose()
df_pub = pd.read_csv('Dataset/publishers.csv')
df_demo = pd.read_csv('Dataset/device_demographics.csv')

# %%
df_user.head(), df_pub.head(), df_demo.head()
# Out:
# (                     0                        1         2
#  Unnamed: 0   device_id                 app_name   minutes
#  0           B-52-23845    Snapchat (Mobile App)   27.9342
#  1           B-52-16587   Pinterest (Mobile App)   14.6664
#  2           B-52-36461    Facebook (Mobile App)  439.7652
#  3           B-52-29089  Yahoo Mail (Mobile App)  900.6606,
#                              app_name        Publisher
#  0               Walmart (Mobile App)         Wal-Mart
#  1        Microsoft Word (Mobile App)  Microsoft Sites
#  2  Sam's Club Scan & Go (Mobile App)         Wal-Mart
#  3             Pinterest (Mobile App)        Pinterest
#  4               YouTube (Mobile App)     Google Sites,
#      device_id  gender_id
#  0  B-52-23845        2.0
#  1  B-52-16587        1.0
#  2  B-52-36461        2.0
#  3  B-52-29089        2.0
#  4  B-52-14212        2.0)

# %%
## Renaming Columns as First row
df_user1 = df_user.rename(columns=df_user.iloc[0]).drop(df_user.index[0])
df_user1.head()
# Out:
#     device_id                 app_name   minutes
# 0  B-52-23845    Snapchat (Mobile App)   27.9342
# 1  B-52-16587   Pinterest (Mobile App)   14.6664
# 2  B-52-36461    Facebook (Mobile App)  439.7652
# 3  B-52-29089  Yahoo Mail (Mobile App)  900.6606
# 4  B-52-14212     Netflix (Mobile App)   17.3502

# %%
# Dropping duplicates
df_user1.drop_duplicates(keep='first',inplace=True)
duplicate = df_user1[df_user1.duplicated(['device_id', 'app_name'])]
duplicate
# Out:
# Empty DataFrame
# Columns: [device_id, app_name, minutes]
# Index: []

# %%
# Dropping duplicates
df_pub.drop_duplicates(keep='first',inplace=True)
duplicate = df_pub[df_pub.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [app_name, Publisher]
# Index: []

# %%
# Dropping duplicates
df_demo.drop_duplicates(keep='first',inplace=True)
duplicate = df_demo[df_demo.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [device_id, gender_id]
# Index: []

# %%
# Checking Null values
df_user1.isnull().sum(), df_pub.isnull().sum(), df_demo.isnull().sum()
# Out:
# (device_id      0
#  app_name       0
#  minutes      748
#  dtype: int64,
#  app_name     0
#  Publisher    0
#  dtype: int64,
#  device_id     0
#  gender_id    98
#  dtype: int64)

# %%
df_user1.columns, df_pub.columns, df_demo.columns
# Out:
# (Index(['device_id', 'app_name', 'minutes'], dtype='object'),
#  Index(['app_name', 'Publisher'], dtype='object'),
#  Index(['device_id', 'gender_id'], dtype='object'))

# %%
df1 = pd.merge(df_user1,df_pub,on='app_name', how='outer')
df1.head()
# Out:
#     device_id               app_name    minutes      Publisher
# 0  B-52-23845  Snapchat (Mobile App)    27.9342  Snapchat, Inc
# 1   B-52-6821  Snapchat (Mobile App)     17.199  Snapchat, Inc
# 2  B-52-21945  Snapchat (Mobile App)   181.7046  Snapchat, Inc
# 3  B-52-24149  Snapchat (Mobile App)   133.3962  Snapchat, Inc
# 4  B-52-28462  Snapchat (Mobile App)  1252.7676  Snapchat, Inc

# %%
df2 = pd.merge(df1, df_demo, on='device_id', how='outer')
df2.head()
# Out:
#     device_id                    app_name  minutes      Publisher  gender_id
# 0  B-52-23845       Snapchat (Mobile App)  27.9342  Snapchat, Inc        2.0
# 1  B-52-23845      Pinterest (Mobile App)   5.5188      Pinterest        2.0
# 2  B-52-23845      Instagram (Mobile App)  867.132       Facebook        2.0
# 3  B-52-23845  Google Search (Mobile App)  236.817   Google Sites        2.0
# 4  B-52-23845        YouTube (Mobile App)  69.6276   Google Sites        2.0

# %%
df2.isnull().sum()
# Out:
# device_id      0
# app_name       0
# minutes      748
# Publisher      0
# gender_id    795
# dtype: int64

# %%
## Checking Duplicates
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [device_id, app_name, minutes, Publisher, gender_id]
# Index: []

# %%
## Sorting based on appname, minutes
df2.sort_values(by=['app_name','minutes'], inplace = True)
df2.head()
# Out:
#         device_id                    app_name minutes     Publisher  gender_id
# 18187  B-52-52155  Amazon Mobile (Mobile App)  0.0378  Amazon Sites        2.0
# 5371   B-52-38817  Amazon Mobile (Mobile App)  0.0756  Amazon Sites        2.0
# 10187   B-52-9082  Amazon Mobile (Mobile App)  0.0756  Amazon Sites        2.0
# 19101  B-52-20729  Amazon Mobile (Mobile App)  0.0756  Amazon Sites        1.0
# 5599   B-52-41002  Amazon Mobile (Mobile App)  0.1134  Amazon Sites        1.0

# %%
## lookup table for GenderId for imputation
df3 = df2.groupby(['app_name','Publisher'])['gender_id'].agg(pd.Series.mode).reset_index(name = "gender_id")
df3.head()
# Out:
#                                      app_name     Publisher  gender_id
# 0                  Amazon Mobile (Mobile App)  Amazon Sites        2.0
# 1  Amazon Music with Prime Music (Mobile App)  Amazon Sites        2.0
# 2                       Facebook (Mobile App)      Facebook        2.0
# 3             Facebook Messenger (Mobile App)      Facebook        2.0
# 4                    Google Play (Mobile App)  Google Sites        2.0

# %%
df4 = pd.merge(df3, df2, how='left', on=['app_name','Publisher'])
df4.head()
# Out:
#                      app_name     Publisher  gender_id_x   device_id minutes  \
# 0  Amazon Mobile (Mobile App)  Amazon Sites          2.0  B-52-52155  0.0378
# 1  Amazon Mobile (Mobile App)  Amazon Sites          2.0  B-52-38817  0.0756
# 2  Amazon Mobile (Mobile App)  Amazon Sites          2.0   B-52-9082  0.0756
# 3  Amazon Mobile (Mobile App)  Amazon Sites          2.0  B-52-20729  0.0756
# 4  Amazon Mobile (Mobile App)  Amazon Sites          2.0  B-52-41002  0.1134
#
#    gender_id_y
# 0          2.0
# 1          2.0
# 2          2.0
# 3          1.0
# 4          1.0

# %%
# replacing "Null" values with Mode of gender Id
df4['gender_id'] = df4['gender_id_y'].fillna(df4['gender_id_x'])
df4 = df4.drop(['gender_id_x','gender_id_y'], axis=1)
df4.head()
# Out:
#                      app_name     Publisher   device_id minutes  gender_id
# 0  Amazon Mobile (Mobile App)  Amazon Sites  B-52-52155  0.0378        2.0
# 1  Amazon Mobile (Mobile App)  Amazon Sites  B-52-38817  0.0756        2.0
# 2  Amazon Mobile (Mobile App)  Amazon Sites   B-52-9082  0.0756        2.0
# 3  Amazon Mobile (Mobile App)  Amazon Sites  B-52-20729  0.0756        1.0
# 4  Amazon Mobile (Mobile App)  Amazon Sites  B-52-41002  0.1134        1.0

# %%
df4.isnull().sum()
# Out:
# app_name       0
# Publisher      0
# device_id      0
# minutes      748
# gender_id      0
# dtype: int64

# %%
## lookup table for Minutes
df5 = df4.groupby(['app_name','Publisher'])['minutes'].agg(pd.Series.median).reset_index(name = "minutes")
df5.head()
# Out:
#                                      app_name     Publisher    minutes
# 0                  Amazon Mobile (Mobile App)  Amazon Sites    47.1555
# 1  Amazon Music with Prime Music (Mobile App)  Amazon Sites    34.3980
# 2                       Facebook (Mobile App)      Facebook  2764.6542
# 3             Facebook Messenger (Mobile App)      Facebook  1349.6490
# 4                    Google Play (Mobile App)  Google Sites    57.6639

# %%
df6 = pd.merge(df4, df5, how='left', on=['app_name','Publisher'])
df6.head()
# Out:
#                      app_name     Publisher   device_id minutes_x  gender_id  \
# 0  Amazon Mobile (Mobile App)  Amazon Sites  B-52-52155    0.0378        2.0
# 1  Amazon Mobile (Mobile App)  Amazon Sites  B-52-38817    0.0756        2.0
# 2  Amazon Mobile (Mobile App)  Amazon Sites   B-52-9082    0.0756        2.0
# 3  Amazon Mobile (Mobile App)  Amazon Sites  B-52-20729    0.0756        1.0
# 4  Amazon Mobile (Mobile App)  Amazon Sites  B-52-41002    0.1134        1.0
#
#    minutes_y
# 0    47.1555
# 1    47.1555
# 2    47.1555
# 3    47.1555
# 4    47.1555

# %%
## Replacing null values with Median
df6['minutes'] = df6['minutes_x'].fillna(df6['minutes_y'])
df6 = df6.drop(['minutes_x','minutes_y'], axis=1)
df6.head()
# Out:
#                      app_name     Publisher   device_id  gender_id minutes
# 0  Amazon Mobile (Mobile App)  Amazon Sites  B-52-52155        2.0  0.0378
# 1  Amazon Mobile (Mobile App)  Amazon Sites  B-52-38817        2.0  0.0756
# 2  Amazon Mobile (Mobile App)  Amazon Sites   B-52-9082        2.0  0.0756
# 3  Amazon Mobile (Mobile App)  Amazon Sites  B-52-20729        1.0  0.0756
# 4  Amazon Mobile (Mobile App)  Amazon Sites  B-52-41002        1.0  0.1134

# %%
df6["minutes"]=df6["minutes"].astype(float)
df6_grp = df6.groupby('app_name')['minutes'].agg(['median', 'std'])
df6_grp['thres'] = df6_grp['std'] + df6_grp['median']
df6_grp.loc['Amazon Mobile (Mobile App)','thres']
# Out:
# 358.37869617823327

# %%
data_list = [row for row in df6.itertuples() if (float(row[5]) <= df6_grp.loc[row[1],'thres'] and float(row[5]) > 30.0)]

# %%
df7 = pd.DataFrame(data_list).set_index('Index')
df7.head()
# Out:
#                          app_name     Publisher   device_id  gender_id  \
# Index
# 155    Amazon Mobile (Mobile App)  Amazon Sites  B-52-36955        1.0
# 156    Amazon Mobile (Mobile App)  Amazon Sites  B-52-32471        2.0
# 157    Amazon Mobile (Mobile App)  Amazon Sites  B-52-10545        2.0
# 158    Amazon Mobile (Mobile App)  Amazon Sites   B-52-9595        2.0
# 159    Amazon Mobile (Mobile App)  Amazon Sites   B-52-3211        2.0
#
#         minutes
# Index
# 155    100.3590
# 156    101.3418
# 157    101.5308
# 158    101.6064
# 159    101.7198

# %%
df8 = df7.groupby('app_name')['minutes'].describe()
df8
# Out:
#                                              count         mean          std  \
# app_name
# Amazon Mobile (Mobile App)                   828.0   119.505818    84.114884
# Amazon Music with Prime Music (Mobile App)   126.0   147.709200   122.798296
# Facebook (Mobile App)                       1910.0  2421.228930  1683.694726
# Facebook Messenger (Mobile App)             1912.0  1396.553956  1138.905491
# Google Play (Mobile App)                    1844.0   127.655345   109.966016
# Google Search (Mobile App)                  1747.0   345.808226   365.273923
# GroupMe (Mobile App)                          92.0   131.112587    86.115822
# Instagram (Mobile App)                      1092.0   465.368365   447.561341
# Kindle (Mobile App)                          129.0   344.901265   397.408270
# Microsoft Word (Mobile App)                   36.0    50.132250    18.736311
# Netflix (Mobile App)                         433.0   457.915573   538.404991
# Outlook (Mobile App)                         211.0   195.718905   152.758532
# Pinterest (Mobile App)                       533.0   211.731771   172.335871
# Sam's Club (Mobile App)                        2.0    50.085000    11.332942
# Sam's Club Scan & Go (Mobile App)              7.0    42.487200    10.284680
# Snapchat (Mobile App)                        823.0   359.985200   321.830439
# Tumblr (Mobile App)                          150.0   537.850908   552.346604
# Walmart (Mobile App)                         301.0    70.683551    35.708477
# Yahoo Mail (Mobile App)                      396.0   248.262000   185.211396
# Yahoo Newsroom (Mobile App)                   45.0   132.171480   105.411083
# YouTube (Mobile App)                        1754.0   519.812217   574.011943
#
#                                                 min        25%        50%  \
# app_name
# Amazon Mobile (Mobile App)                  30.0888   49.28175    86.5809
# Amazon Music with Prime Music (Mobile App)  32.2812   53.97840    98.0343
# Facebook (Mobile App)                       30.6180  926.48745  2307.0852
# Facebook Messenger (Mobile App)             30.6180  428.68980  1172.6883
# Google Play (Mobile App)                    30.0132   53.51535    86.2407
# Google Search (Mobile App)                  30.0132  106.27470   219.7314
# GroupMe (Mobile App)                        30.5424   57.68280   102.9672
# Instagram (Mobile App)                      30.0132  111.48165   252.4473
# Kindle (Mobile App)                         30.9204   51.25680   168.3990
# Microsoft Word (Mobile App)                 30.6558   34.93665    45.5679
# Netflix (Mobile App)                        30.4290   79.49340   207.5598
# Outlook (Mobile App)                        30.1266   69.87330   129.6162
# Pinterest (Mobile App)                      30.3156   86.07060   133.4340
# Sam's Club (Mobile App)                     42.0714   46.07820    50.0850
# Sam's Club Scan & Go (Mobile App)           33.6420   37.45980    38.3670
# Snapchat (Mobile App)                       30.1266  113.49450   214.4016
# Tumblr (Mobile App)                         30.3156  159.25140   302.3055
# Walmart (Mobile App)                        30.0510   40.03020    61.3494
# Yahoo Mail (Mobile App)                     30.4290   99.55575   177.9435
# Yahoo Newsroom (Mobile App)                 30.0888   58.02300    99.2250
# YouTube (Mobile App)                        30.0888  110.29095   262.7667
#
#                                                    75%        max
# app_name
# Amazon Mobile (Mobile App)                   167.35950   357.8526
# Amazon Music with Prime Music (Mobile App)   210.82950   477.7164
# Facebook (Mobile App)                       3681.78615  5995.2312
# Facebook Messenger (Mobile App)             2101.08465  4386.3120
# Google Play (Mobile App)                     162.72900   601.7382
# Google Search (Mobile App)                   432.52650  1990.3968
# GroupMe (Mobile App)                         190.40805   329.9940
# Instagram (Mobile App)                       728.84070  1724.3226
# Kindle (Mobile App)                          482.89500  1641.2382
# Microsoft Word (Mobile App)                   56.41650   103.2318
# Netflix (Mobile App)                         608.76900  2393.0802
# Outlook (Mobile App)                         300.13200   586.0512
# Pinterest (Mobile App)                       314.15580   715.3650
# Sam's Club (Mobile App)                       54.09180    58.0986
# Sam's Club Scan & Go (Mobile App)             43.35660    63.7686
# Snapchat (Mobile App)                        537.32700  1250.0460
# Tumblr (Mobile App)                          733.30110  2255.2236
# Walmart (Mobile App)                          91.74060   156.4164
# Yahoo Mail (Mobile App)                      376.41240   724.2858
# Yahoo Newsroom (Mobile App)                  179.58780   432.0918
# YouTube (Mobile App)                         714.99645  2497.5216

# %%
df9 = df7.groupby(['app_name','gender_id'])['minutes'].describe()
df9
# Out:
#                                                        count         mean  \
# app_name                                   gender_id
# Amazon Mobile (Mobile App)                 1.0         304.0   121.036843
#                                            2.0         524.0   118.617590
# Amazon Music with Prime Music (Mobile App) 1.0          37.0   158.794735
#                                            2.0          89.0   143.100607
# Facebook (Mobile App)                      1.0         718.0  2453.191624
#                                            2.0        1192.0  2401.976233
# Facebook Messenger (Mobile App)            1.0         683.0  1415.977927
#                                            2.0        1229.0  1385.759349
# Google Play (Mobile App)                   1.0         682.0   128.698192
#                                            2.0        1162.0   127.043279
# Google Search (Mobile App)                 1.0         637.0   359.079587
#                                            2.0        1110.0   338.192139
# GroupMe (Mobile App)                       1.0          26.0   125.956869
#                                            2.0          66.0   133.143627
# Instagram (Mobile App)                     1.0         395.0   445.352710
#                                            2.0         697.0   476.711527
# Kindle (Mobile App)                        1.0          54.0   402.484600
#                                            2.0          75.0   303.441264
# Microsoft Word (Mobile App)                1.0           9.0    44.755200
#                                            2.0          27.0    51.924600
# Netflix (Mobile App)                       1.0         161.0   447.732313
#                                            2.0         272.0   463.943164
# Outlook (Mobile App)                       1.0          64.0   202.636941
#                                            2.0         147.0   192.706971
# Pinterest (Mobile App)                     1.0         162.0   239.335833
#                                            2.0         371.0   199.678245
# Sam's Club (Mobile App)                    1.0           1.0    58.098600
#                                            2.0           1.0    42.071400
# Sam's Club Scan & Go (Mobile App)          1.0           3.0    46.279800
#                                            2.0           4.0    39.642750
# Snapchat (Mobile App)                      1.0         287.0   365.329493
#                                            2.0         536.0   357.123610
#                                            2.0          41.31540    47.4390
# Snapchat (Mobile App)                      1.0         538.53660  1250.0460
#                                            2.0         535.69215  1249.5168
# Tumblr (Mobile App)                        1.0         517.44420  1778.5278
#                                            2.0         916.39485  2255.2236
# Walmart (Mobile App)                       1.0          83.46240   154.9044
#                                            2.0          95.44500   156.4164
# Yahoo Mail (Mobile App)                    1.0         403.00470   724.2858
#                                            2.0         360.80100   701.3034
# Yahoo Newsroom (Mobile App)                1.0         130.77855   406.1988
#                                            2.0         186.35400   432.0918
# YouTube (Mobile App)                       1.0         739.23570  2497.5216
#                                            2.0         706.93560  2487.3534

# %%
# Writing into CSV Files
df8.to_csv('usage_statastical_info_based_on_app_name.csv')
df9.to_csv('usage_statastical_info_based_on_app_name_and_gender_id.csv')

# %%
df10= df7.groupby('app_name')['minutes'].agg(('sum','count','mean')).reset_index()
df10.rename(columns={'sum':'total_minutes','count':'total_devices','mean':'Avg_time_spend_per_device'}, inplace=True)
df10
# Out:
#                                       app_name  total_minutes  total_devices  \
# 0                   Amazon Mobile (Mobile App)   9.895082e+04            828
# 1   Amazon Music with Prime Music (Mobile App)   1.861136e+04            126
# 2                        Facebook (Mobile App)   4.624547e+06           1910
# 3              Facebook Messenger (Mobile App)   2.670211e+06           1912
# 4                     Google Play (Mobile App)   2.353965e+05           1844
# 5                   Google Search (Mobile App)   6.041270e+05           1747
# 6                         GroupMe (Mobile App)   1.206236e+04             92
# 7                       Instagram (Mobile App)   5.081823e+05           1092
# 8                          Kindle (Mobile App)   4.449226e+04            129
# 9                  Microsoft Word (Mobile App)   1.804761e+03             36
# 10                        Netflix (Mobile App)   1.982774e+05            433
# 11                        Outlook (Mobile App)   4.129669e+04            211
# 12                      Pinterest (Mobile App)   1.128530e+05            533
# 13                     Sam's Club (Mobile App)   1.001700e+02              2
# 14           Sam's Club Scan & Go (Mobile App)   2.974104e+02              7
# 15                       Snapchat (Mobile App)   2.962678e+05            823
# 16                         Tumblr (Mobile App)   8.067764e+04            150
# 17                        Walmart (Mobile App)   2.127575e+04            301
# 18                     Yahoo Mail (Mobile App)   9.831175e+04            396
# 19                 Yahoo Newsroom (Mobile App)   5.947717e+03             45
# 20                        YouTube (Mobile App)   9.117506e+05           1754
#
#     Avg_time_spend_per_device
# 0                  119.505818
# 1                  147.709200
# 2                 2421.228930
# 3                 1396.553956
# 4                  127.655345
# 5                  345.808226
# 6                  131.112587
# 7                  465.368365
# 8                  344.901265
# 9                   50.132250
# 10                 457.915573
# 11                 195.718905
# 12                 211.731771
# 13                  50.085000
# 14                  42.487200
# 15                 359.985200
# 16                 537.850908
# 17                  70.683551
# 18                 248.262000
# 19                 132.171480
# 20                 519.812217

# %%
df10['Rank (user based)']= df10['total_devices'].rank(ascending=False)
df10['Rank (Duration based)'] = df10['total_minutes'].rank(ascending=False)
df10
# Out:
#                                       app_name  total_minutes  total_devices  \
# 0                   Amazon Mobile (Mobile App)   9.895082e+04            828
# 1   Amazon Music with Prime Music (Mobile App)   1.861136e+04            126
# 2                        Facebook (Mobile App)   4.624547e+06           1910
# 3              Facebook Messenger (Mobile App)   2.670211e+06           1912
# 4                     Google Play (Mobile App)   2.353965e+05           1844
# 5                   Google Search (Mobile App)   6.041270e+05           1747
# 6                         GroupMe (Mobile App)   1.206236e+04             92
# 7                       Instagram (Mobile App)   5.081823e+05           1092
# 8                          Kindle (Mobile App)   4.449226e+04            129
# 9                  Microsoft Word (Mobile App)   1.804761e+03             36
# 10                        Netflix (Mobile App)   1.982774e+05            433
# 11                        Outlook (Mobile App)   4.129669e+04            211
# 12                      Pinterest (Mobile App)   1.128530e+05            533
# 13                     Sam's Club (Mobile App)   1.001700e+02              2
# 14           Sam's Club Scan & Go (Mobile App)   2.974104e+02              7
# 15                       Snapchat (Mobile App)   2.962678e+05            823
# 16                         Tumblr (Mobile App)   8.067764e+04            150
# 17                        Walmart (Mobile App)   2.127575e+04            301
# 18                     Yahoo Mail (Mobile App)   9.831175e+04            396
# 19                 Yahoo Newsroom (Mobile App)   5.947717e+03             45
# 20                        YouTube (Mobile App)   9.117506e+05           1754
#
#     Avg_time_spend_per_device  Rank (user based)  Rank (Duration based)
# 0                  119.505818                7.0                   10.0
# 1                  147.709200               16.0                   16.0
# 2                 2421.228930                2.0                    1.0
# 3                 1396.553956                1.0                    2.0
# 4                  127.655345                3.0                    7.0
# 5                  345.808226                5.0                    4.0
# 6                  131.112587               17.0                   17.0
# 7                  465.368365                6.0                    5.0
# 8                  344.901265               15.0                   13.0
# 9                   50.132250               19.0                   19.0
# 10                 457.915573               10.0                    8.0
# 11                 195.718905               13.0                   14.0
# 12                 211.731771                9.0                    9.0
# 13                  50.085000               21.0                   21.0
# 14                  42.487200               20.0                   20.0
# 15                 359.985200                8.0                    6.0
# 16                 537.850908               14.0                   12.0
# 17                  70.683551               12.0                   15.0
# 18                 248.262000               11.0                   11.0
# 19                 132.171480               18.0                   18.0
# 20                 519.812217                4.0                    3.0

# %%
df10.to_csv('ranking_info_based_on_appname.csv')

# %%
df10['Publisher'] = df10['app_name'].apply(lambda x: df_pub.loc[df_pub[df_pub['app_name']== x].index[0], 'Publisher'])
df10
# Out:
#                                       app_name  total_minutes  total_devices  \
# 0                   Amazon Mobile (Mobile App)   9.895082e+04            828
# 1   Amazon Music with Prime Music (Mobile App)   1.861136e+04            126
# 2                        Facebook (Mobile App)   4.624547e+06           1910
# 3              Facebook Messenger (Mobile App)   2.670211e+06           1912
# 4                     Google Play (Mobile App)   2.353965e+05           1844
# 5                   Google Search (Mobile App)   6.041270e+05           1747
# 6                         GroupMe (Mobile App)   1.206236e+04             92
# 7                       Instagram (Mobile App)   5.081823e+05           1092
# 8                          Kindle (Mobile App)   4.449226e+04            129
# 9                  Microsoft Word (Mobile App)   1.804761e+03             36
# 10                        Netflix (Mobile App)   1.982774e+05            433
# 11                        Outlook (Mobile App)   4.129669e+04            211
# 12                      Pinterest (Mobile App)   1.128530e+05            533
# 13                     Sam's Club (Mobile App)   1.001700e+02              2
# 14           Sam's Club Scan & Go (Mobile App)   2.974104e+02              7
# 15                       Snapchat (Mobile App)   2.962678e+05            823
# 16                         Tumblr (Mobile App)   8.067764e+04            150
# 17                        Walmart (Mobile App)   2.127575e+04            301
# 18                     Yahoo Mail (Mobile App)   9.831175e+04            396
# 19                 Yahoo Newsroom (Mobile App)   5.947717e+03             45
# 20                        YouTube (Mobile App)   9.117506e+05           1754
#
#     Avg_time_spend_per_device  Rank (user based)  Rank (Duration based)  \
# 0                  119.505818                7.0                   10.0
# 1                  147.709200               16.0                   16.0
# 2                 2421.228930                2.0                    1.0
# 3                 1396.553956                1.0                    2.0
# 4                  127.655345                3.0                    7.0
# 5                  345.808226                5.0                    4.0
# 6                  131.112587               17.0                   17.0
# 7                  465.368365                6.0                    5.0
# 8                  344.901265               15.0                   13.0
# 9                   50.132250               19.0                   19.0
# 10                 457.915573               10.0                    8.0
# 11                 195.718905               13.0                   14.0
# 12                 211.731771                9.0                    9.0
# 13                  50.085000               21.0                   21.0
# 14                  42.487200               20.0                   20.0
# 15                 359.985200                8.0                    6.0
# 16                 537.850908               14.0                   12.0
# 17                  70.683551               12.0                   15.0
# 18                 248.262000               11.0                   11.0
# 19                 132.171480               18.0                   18.0
# 20                 519.812217                4.0                    3.0
#
#           Publisher
# 0      Amazon Sites
# 1      Amazon Sites
# 2          Facebook
# 3          Facebook
# 4      Google Sites
# 5      Google Sites
# 6   Microsoft Sites
# 7          Facebook
# 8      Amazon Sites
# 9   Microsoft Sites
# 10     Netflix Inc.
# 11  Microsoft Sites
# 12        Pinterest
# 13         Wal-Mart
# 14         Wal-Mart
# 15    Snapchat, Inc
# 16             Oath
# 17         Wal-Mart
# 18             Oath
# 19             Oath
# 20     Google Sites

# %%
# Changing Columns Order
column_names = ['app_name','Publisher', 'total_minutes', 'total_devices','Avg_time_spend_per_device', 'Rank (user based)','Rank (Duration based)']
df11 = df10[column_names]
df11.columns
# Out:
# Index(['app_name', 'Publisher', 'total_minutes', 'total_devices',
#        'Avg_time_spend_per_device', 'Rank (user based)',
#        'Rank (Duration based)'],
#       dtype='object')

# %%
df11.head()
# Out:
#                                      app_name     Publisher  total_minutes  \
# 0                  Amazon Mobile (Mobile App)  Amazon Sites   9.895082e+04
# 1  Amazon Music with Prime Music (Mobile App)  Amazon Sites   1.861136e+04
# 2                       Facebook (Mobile App)      Facebook   4.624547e+06
# 3             Facebook Messenger (Mobile App)      Facebook   2.670211e+06
# 4                    Google Play (Mobile App)  Google Sites   2.353965e+05
#
#    total_devices  Avg_time_spend_per_device  Rank (user based)  \
# 0            828                 119.505818                7.0
# 1            126                 147.709200               16.0
# 2           1910                2421.228930                2.0
# 3           1912                1396.553956                1.0
# 4           1844                 127.655345                3.0
#
#    Rank (Duration based)
# 0                   10.0
# 1                   16.0
# 2                    1.0
# 3                    2.0
# 4                    7.0

# %%
df11.to_csv('ranking_info_based_on_appname_publisher.csv')
